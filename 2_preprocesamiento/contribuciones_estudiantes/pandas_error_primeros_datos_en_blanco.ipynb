# %% [markdown]
# <a href="https://colab.research.google.com/github/novilove/sic_ai_2025_sept/blob/main/2_preprocesamiento/contribuciones_estudiantes/pandas_error_primeros_datos_en_blanco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# archivo desde https://datos.gob.cl/dataset/subsidio-discapacidad-mental-sdm


# data = pd.read_csv(
#     '/content/sd_082025.csv',
#     header=6,
#     skipinitialspace=5,
#     skiprows=5
#     skip_blank_lines=True
# )


data = pd.read_csv(
    '/content/sd_082025.csv',
    skiprows=5,
    sep=";"
)

print(data)
#data.head(10) # primeros datos
#data.tail(10) # ultimos datos
# Out:
#                                                 Región  Cód Comuna  \
# 338                                                 13     13504.0
# 339                                                 13     13505.0
# 340                                                 13     13601.0
# 341                                                 13     13602.0
# 342                                                 13     13603.0
# 343                                                 13     13604.0
# 344                                                 13     13605.0
# 345                                             Total          NaN
# 346                                                NaN         NaN
# 347  Nota: Incluye la Discapacidad Mental, Física o...         NaN
#
#       Glosa Comuna   N° Hombre  Mto.Hombre  Nº Mujer  Mto.Mujer       Nº  \
# 338    MARIA PINTO        13.0       1.456    47.000      5.264   60.000
# 339      SAN PEDRO        11.0       1.195    44.000      4.820   55.000
# ...
