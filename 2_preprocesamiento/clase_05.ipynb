# %% [markdown]
# <a href="https://colab.research.google.com/github/davidlealo/sic_ai_2025_sept/blob/main/2_preprocesamiento/clase_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase 5: Pandas
#
# sábado 13 de septiembre, 2025

# %%
# Importar pandas https://pandas.pydata.org/

import pandas as pd

# %%
# Crear una serie con pandas

pd.Series(['Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female'])
# Out:
# 0      Male
# 1    Female
# 2      Male
# 3      Male
# 4    Female
# 5    Female
# 6    Female
# dtype: object

# %%
# Crear una Serie a partir de un numpy array

import numpy as np

arr = np.array(['Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female'])

pd.Series(arr)
# Out:
# 0      Male
# 1    Female
# 2      Male
# 3      Male
# 4    Female
# 5    Female
# 6    Female
# dtype: object

# %%
serie_vieja = pd.Series(arr)

# %%
serie_vieja.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
serie_vieja.values
# Out:
# array(['Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female'],
#       dtype=object)

# %%
# Crear una Serie a partir de un numpy array

import numpy as np

pd.Series(np.array(['Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female']))
# Out:
# 0      Male
# 1    Female
# 2      Male
# 3      Male
# 4    Female
# 5    Female
# 6    Female
# dtype: object

# %%
type(pd.Series(np.array(['Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female'])))
# Out:
# pandas.core.series.Series

# %%
# Tenemos un diccionario

dict_data={'a':1, 'b':2, 'c':3}

# %%
dict_data
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
type(dict_data)
# Out:
# dict

# %%
pd.Series(dict_data)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
ser1 = pd.Series(dict_data)

# %%
ser1.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
ser1.values
# Out:
# array([1, 2, 3])

# %%
# Crear series a base de una lista

list_data=['2019-01-02', 3.14, 'ABC', 100, True]

# %%
ser2=pd.Series(list_data)

# %%
type(ser2)
# Out:
# pandas.core.series.Series

# %%
ser2.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
ser2.values
# Out:
# array(['2019-01-02', 3.14, 'ABC', 100, True], dtype=object)

# %%
# Crear un dataframe

pd.DataFrame({"Name": ["Braund, Mr, Owen Harries",
                       "Allen, Mr. William Henry",
                       "Bonnel, Miss. Elizabeth"],
              "Age": [22, 35, 58],
              "Sex": ["male", "make", "female"]})
# Out:
#                        Name  Age     Sex
# 0  Braund, Mr, Owen Harries   22    male
# 1  Allen, Mr. William Henry   35    make
# 2   Bonnel, Miss. Elizabeth   58  female
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('Sex').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# ...

# %%
pd.DataFrame({"Name": ["Braund, Mr, Owen Harries",
                       "Allen, Mr. William Henry",
                       "Bonnel, Miss. Elizabeth"],
              "Age": [22, 35, 58],
              "Sex": ["male", "make", "female"]})
# Out:
#                        Name  Age     Sex
# 0  Braund, Mr, Owen Harries   22    male
# 1  Allen, Mr. William Henry   35    make
# 2   Bonnel, Miss. Elizabeth   58  female

# %%
# Cargar datos desde distintas fuentes desde https://datos.gob.cl/

pensiones_082025 = pd.read_csv('/content/pens_prev._vigentes_082025.csv', sep=";")

pensiones_082025 # https://datos.gob.cl/dataset/pensiones-previsionales-vigentes
# Out:
#     PENSIONES PREVISIONALES DEL SISTEMA DE REPARTO   Unnamed: 1  \
# 0                                       01-08-2025          NaN
# 1                   (Número y Monto en miles de $)          NaN
# 2                                              NaN          NaN
# 3                                           Región  Cód. Comuna
# 4                                               15        15101
# ..                                             ...          ...
# 346                                             13        13602
# 347                                             13        13603
# 348                                             13        13604
# 349                                             13        13605
# 350                                          Total          NaN
#
#         Unnamed: 2  Unnamed: 3   Unnamed: 4 Unnamed: 5   Unnamed: 6  \
# 0              NaN         NaN          NaN        NaN          NaN
# ...

# %%
# Cantidad de controles de identidad

controles_1er_trimestre_2025 = pd.read_excel('/content/cantidad-de-controles-de-identidad-art-85-2025 (1).xls')

controles_1er_trimestre_2025 # https://datos.gob.cl/dataset/cantidad-de-delitos-y-faltas-investigadas-art-18
# Out:
#                                                ART.85 Unnamed: 1 Unnamed: 2  \
# 0                                   REGION UNIDAD PDI      ENERO    FEBRERO
# 1                                     Región de Aysén          0          0
# 2                               Región de Antofagasta          0          0
# 3                        Región de Arica y Parinacota          0          0
# 4                                   Región de Atacama          0          0
# 5                                  Región de Coquimbo          0          0
# 6                              Región de la Araucania          0          0
# 7                                 Región de los Lagos          0          0
# 8                                  Región de los Ríos          0          0
# 9                                Región de Magallanes          0          0
# 10                                 Región de Tarapacá          0          0
# ...

# %%
# Cargar estos datos https://datos.gob.cl/dataset/subsidio-discapacidad-mental-sdm

import pandas as pd

df = pd.read_csv("sd_082025.csv",
                 skiprows=6,
                 sep=";",
                 engine="python")

print(df.head())
# Out:
#    15    15102      CAMARONES    170  18.984    701   78.450    871   97.434
# 0  15  15201.0          PUTRE    0.0       0    1.0  112,002    1.0  112,002
# 1  15  15202.0  GENERAL LAGOS    0.0       0    1.0  112,002    1.0  112,002
# 2   1   1101.0        IQUIQUE    0.0       0    1.0  112,002    1.0  112,002
# 3   1   1107.0  ALTO HOSPICIO  127.0  14.224  563.0   63.057  690.0   77.281
# 4   1   1401.0   POZO ALMONTE  111.0  12.432  573.0   64.084  684.0   76.516

# %% [markdown]
# # Cómo cargar un CSV con membrete y comas en los números en Pandas
#
# Cuando un archivo CSV no está limpio, pueden aparecer errores como:
#
#     ParserError: Error tokenizing data. C error: Expected X fields in line Y, saw Z
#
# Esto ocurre generalmente por dos motivos:\
# 1. El archivo tiene filas de membrete antes de la cabecera real de
# datos.\
# 2. Los números vienen con comas (`112,002`) que Pandas interpreta como
# separador de columnas.
#
# ------------------------------------------------------------------------
#
# ## Paso 1: Saltar las filas del membrete
#
# En el ejemplo, los datos reales empiezan en la fila 7.\
# Por eso usamos `skiprows=6` para ignorar las 6 primeras filas:
#
# ``` python
# df = pd.read_csv("sd_082025.csv", skiprows=6)
# ```
#
# ------------------------------------------------------------------------
#
# ## Paso 2: Especificar el separador correcto
#
# Muchos CSV en Chile usan punto y coma (`;`) como delimitador, porque la
# coma se usa en los números.\
# Si no lo indicamos, Pandas se confunde.
#
# ``` python
# df = pd.read_csv("sd_082025.csv", skiprows=6, sep=";", engine="python")
# ```
#
# ------------------------------------------------------------------------
#
# ## Paso 3: Interpretar las comas en los números
#
# Los montos vienen con formato `112,002`. Pandas puede entender esa coma
# como separador de miles:
#
# ``` python
# df = pd.read_csv(
#     "sd_082025.csv",
#     skiprows=6,
#     sep=";",        # separador de columnas
#     thousands=",",  # interpreta 112,002 como 112002
#     engine="python"
# )
# ```
#
# ------------------------------------------------------------------------
#
# ## Paso 4: Revisar las primeras líneas del archivo
#
# Si no estás seguro del separador, imprime unas filas:
#
# ``` python
# with open("sd_082025.csv", "r", encoding="utf-8") as f:
#     for i in range(15):
#         print(f.readline())
# ```
#
# Esto permite confirmar si el delimitador es `;`, `,` o tabulación.
#
# ------------------------------------------------------------------------
#
# ## Resultado esperado
#
# Después de estos pasos deberías tener un DataFrame limpio con columnas
# como:
#
# -   Región\
# -   Cód Comuna\
# -   Glosa Comuna\
# -   N° Hombre\
# -   Mto.Hombre\
# -   N° Mujer\
# -   Mto.Mujer\
# -   N°\
# -   Monto m\$

# %%
# Carga de archivo parquet desde https://datos.gob.cl/dataset/operaciones-aeronaves


import pandas as pd

df = pd.read_parquet('/content/bitacora-vuelos (2).parquet')

df.head()
# Out:
#                       dt_operacion aeropuerto_oaci tipo_operacion  \
# 0        1999-12-31 21:00:00-03:00            SCEL              A
# 1        1999-12-31 21:00:00-03:00            SCTC              D
# 2 1999-12-31 21:04:00.001000-03:00            SCEL              A
# 3        1999-12-31 21:08:00-03:00            SCFA              A
# 4        1999-12-31 21:08:00-03:00            SCFA              A
#
#   aeropuerto_dgac_orig_dest aerolinea_dgac numero_vuelo actividad_cod  \
# 0                      SPIM            LAN          631             U
# 1                      SCUG              6            0             P
# 2                      SCTC            LAN         4248             U
# 3                      SCEL            LCO         2395             U
# 4                      SCEL            LCO         2394             U
#
#   matricula modelo_avion modelo_avion_desc  es_internacional        pmd
# 0     CCCDM         B763         767-352ER              True  187.00000
# ...

# %%
import pandas as pd


file_path = '/content/bitacora-vuelos (2).parquet'

# Intentar con pyarrow (el motor por defecto)
try:
    df = pd.read_parquet(file_path, engine='pyarrow')

    print("Leído con pyarrow")
except Exception as e:
    print("Error con pyarrow:", e)
    # Intentar con fastparquet
    try:
        df = pd.read_parquet(file_path, engine='fastparquet')
        print("Leído con fastparquet")
    except Exception as e2:
        print("Error con fastparquet:", e2)
        df = None

if df is not None:
    display(df.head(10))
else:
    print("No se pudo leer el archivo Parquet.")
# Out:
# Leído con pyarrow
#                       dt_operacion aeropuerto_oaci tipo_operacion  \
# 0        1999-12-31 21:00:00-03:00            SCEL              A
# 1        1999-12-31 21:00:00-03:00            SCTC              D
# 2 1999-12-31 21:04:00.001000-03:00            SCEL              A
# 3        1999-12-31 21:08:00-03:00            SCFA              A
# 4        1999-12-31 21:08:00-03:00            SCFA              A
# 5        1999-12-31 21:16:00-03:00            SCTB              A
# 6        1999-12-31 21:21:00-03:00            SCTC              A
# 7        1999-12-31 21:21:00-03:00            SCEL              A
# 8        1999-12-31 21:24:00-03:00            SCEL              A
# 9        1999-12-31 21:30:00-03:00            SCEL              D
#
#   aeropuerto_dgac_orig_dest aerolinea_dgac numero_vuelo actividad_cod  \
# 0                      SPIM            LAN          631             U
# 1                      SCUG              6            0             P
# ...

# %%
# Leer columnas de dataframe

# Primero vamos a crear un dataframe desde un dict y lo vamos a guardar en una variable df

df=pd.DataFrame({"Name": ["Braund, Mr, Owen Harries",
                       "Allen, Mr. William Henry",
                       "Bonnel, Miss. Elizabeth"],
              "Age": [22, 35, 58],
              "Sex": ["male", "make", "female"]})

# %%
df
# Out:
#                        Name  Age     Sex
# 0  Braund, Mr, Owen Harries   22    male
# 1  Allen, Mr. William Henry   35    make
# 2   Bonnel, Miss. Elizabeth   58  female

# %%
# Dos formas de acceder a la información de las columnas

df.Age
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
df["Age"]
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.Age)
# Out:
# pandas.core.series.Series

# %%
df.Name[0]
# Out:
# 'Braund, Mr, Owen Harries'

# %%
df["Name"][1]
# Out:
# 'Allen, Mr. William Henry'

# %%
# Crear un df desde un grupo de listas

df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,0]])

# %%
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  0

# %%
df[1][1]
# Out:
# np.int64(5)

# %%
df[2][1]
# Out:
# np.int64(6)

# %%
eye=pd.Series({'Brown':220, 'Blue':215, 'Hazel':93, 'Green':64})

# %%
eye
# Out:
# Brown    220
# Blue     215
# Hazel     93
# Green     64
# dtype: int64

# %%
eye.index
# Out:
# Index(['Brown', 'Blue', 'Hazel', 'Green'], dtype='object')

# %%
eye.name

# %%
eye.name="eye_color"

# %%
eye
# Out:
# Brown    220
# Blue     215
# Hazel     93
# Green     64
# Name: eye_color, dtype: int64

# %%
eye.sort_values()
# Out:
# Green     64
# Hazel     93
# Blue     215
# Brown    220
# Name: eye_color, dtype: int64

# %%
eye.sort_values(ascending=False) # https://pandas.pydata.org/docs/reference/api/pandas.Series.sort_values.html
# Out:
# Brown    220
# Blue     215
# Hazel     93
# Green     64
# Name: eye_color, dtype: int64

# %%
eye.sort_index()
# Out:
# Blue     215
# Brown    220
# Green     64
# Hazel     93
# Name: eye_color, dtype: int64

# %%
eye2 = pd.Series({'Brown':220, 'Blue':215, 'Blues':33, 'Bluei':33, 'Hazel':93, 'Green':64})

# %%
eye2.unique()
# Out:
# array([220, 215,  33,  93,  64])

# %%
eye2.nunique()
# Out:
# 5

# %%
eye.unique()
# Out:
# array([220, 215,  93,  64])

# %%
eye2.value_counts()
# Out:
# 220    1
# 33     1
# 93     1
# 64     1
# Name: count, dtype: int64

# %%
my_data2=[220, 215, 93, 64, 64]

# %%
eye2=pd.Series(data=my_data2, index=['Brown', 'Blue', 'Blue', 'Hazel', 'Green'])

# %%
eye2.unique()
# Out:
# array([220, 215,  93,  64])

# %%
eye2.nunique()
# Out:
# 4

# %%
eye2.value_counts()
# Out:
# 64     2
# 220    1
# 215    1
# 93     1
# Name: count, dtype: int64

# %%
# Slicing & indexing en series de pandas

ser=pd.Series([0,10,20,30,40], index=['a','b','c','d','e'])

# %%
# Los valores tienen posiciones partiendo desde el 0 en adelante

ser
# Out:
# a     0
# b    10
# c    20
# d    30
# e    40
# dtype: int64

# %%
ser[1]
# Out:
# /tmp/ipython-input-4267038266.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ser[1]
# np.int64(10)

# %%
# En este caso que está nombrado el index con una letra la posición es 1 y también es 'b'

ser['b']
# Out:
# np.int64(10)

# %%
ser.b
# Out:
# np.int64(10)

# %%
ser[1:3]
# Out:
# b    10
# c    20
# dtype: int64

# %%
# Operaciones con series

ser1=pd.Series([0,1,2,3,4], index=[0,1,2,3,4])
ser2=pd.Series([0,1,2,3,4], index=[4,3,2,1,0])

# %%
ser1
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
ser2
# Out:
# 4    0
# 3    1
# 2    2
# 1    3
# 0    4
# dtype: int64

# %%
ser1+ser2
# Out:
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4
# dtype: int64

# %%
ser1*ser2
# Out:
# 0    0
# 1    3
# 2    4
# 3    3
# 4    0
# dtype: int64

# %%
ser1/ser2
# Out:
# 0    0.000000
# 1    0.333333
# 2    1.000000
# 3    3.000000
# 4         inf
# dtype: float64

# %%
# Estadísticos con series

ser1.sum()
# Out:
# np.int64(10)

# %%
ser1.mean()
# Out:
# np.float64(2.0)

# %%
ser1.median()
# Out:
# 2.0

# %%
ser1.min()
# Out:
# 0

# %%
ser1.std()
# Out:
# 1.5811388300841898

# %%
# Aplicar función lambda en Series con apply

ser_height=pd.Series([160,170,180],name='height')

# %%
ser_height
# Out:
# 0    160
# 1    170
# 2    180
# Name: height, dtype: int64

# %%
plus_10=lambda x:x+10

# %%
plus_10(5)
# Out:
# 15

# %%
ser_height.apply(lambda x:x+10)
# Out:
# 0    170
# 1    180
# 2    190
# Name: height, dtype: int64

# %%
# Cargar un df desde un url conocido con wget

# !wget https://raw.githubusercontent.com/davidlealo/sic_ai_2025_jun/refs/heads/main/02preprocesamiento/chapter3/data_Iris.csv
# Out:
# --2025-09-13 13:16:23--  https://raw.githubusercontent.com/davidlealo/sic_ai_2025_jun/refs/heads/main/02preprocesamiento/chapter3/data_Iris.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3858 (3.8K) [text/plain]
# Saving to: ‘data_Iris.csv’
#
# data_Iris.csv       100%[===================>]   3.77K  --.-KB/s    in 0s
#
# 2025-09-13 13:16:23 (37.2 MB/s) - ‘data_Iris.csv’ saved [3858/3858]

# %%
pd.read_csv('data_Iris.csv')
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Diferencias al ojo humano de la flor de iris
#
# Fotos de muestra:
# ![Tipos de flor de iris: setosa, versicolor y virginica](https://www.sakurai.dev.br/assets/images/posts/2018-10-17-classificacao-iris-01.png)
#
#
#
# otras fotos de muestra:
# ![Tipos de flor de iris: setosa, versicolor y virginica](https://miro.medium.com/v2/resize:fit:1400/1*f6KbPXwksAliMIsibFyGJw.png)

# %%
iris_df = pd.read_csv('data_Iris.csv')

# %%
type(iris_df)
# Out:
# pandas.core.frame.DataFrame

# %%
iris_df.head(10)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
iris_df.tail()
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_df['Sepal.Length'].unique()
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.4, 4.8, 4.3, 5.8, 5.7, 5.2, 5.5,
#        4.5, 5.3, 7. , 6.4, 6.9, 6.5, 6.3, 6.6, 5.9, 6. , 6.1, 5.6, 6.7,
#        6.2, 6.8, 7.1, 7.6, 7.3, 7.2, 7.7, 7.4, 7.9])

# %%
iris_df['Sepal.Length'].nunique()
# Out:
# 35

# %%
iris_df[['Sepal.Length', 'Sepal.Width']]
# Out:
#      Sepal.Length  Sepal.Width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %%
iris_df[['Sepal.Length', 'Sepal.Width']].value_counts()
# Out:
# Sepal.Length  Sepal.Width
# 5.8           2.7            4
# 4.9           3.1            3
# 6.9           3.1            3
# 5.1           3.8            3
# 6.5           3.0            3
#                             ..
# 7.7           2.6            1
#               2.8            1
#               3.0            1
#               3.8            1
# 7.9           3.8            1
# Name: count, Length: 116, dtype: int64

# %%
# Cuidado al crear df con listas sin indicar el rol en el df (si es columna o valor)

df=pd.DataFrame([['Name','Age','Sex','School'],['Tom',15,'Male','middle'],['Alice',10,'Female','elementary']])
df
# Out:
#        0    1       2           3
# 0   Name  Age     Sex      School
# 1    Tom   15    Male      middle
# 2  Alice   10  Female  elementary

# %%
df=pd.DataFrame([['Tom',15,'Male','middle'],['Alice',10,'Female','elementary']], columns=['Name','Age','Sex','School'])

# %%
df
# Out:
#     Name  Age     Sex      School
# 0    Tom   15    Male      middle
# 1  Alice   10  Female  elementary

# %%
df.columns=['nombre', 'edad', 'sexo', 'educacion']

# %%
df
# Out:
#   nombre  edad    sexo   educacion
# 0    Tom    15    Male      middle
# 1  Alice    10  Female  elementary

# %%
df.index= ['alumno1', 'alumno2']

# %%
df
# Out:
#         nombre  edad    sexo   educacion
# alumno1    Tom    15    Male      middle
# alumno2  Alice    10  Female  elementary

# %%
# Si quiero renombrar un índice o una columna en específico

df.rename(columns={'edad':'age'})
# Out:
#         nombre  age    sexo   educacion
# alumno1    Tom   15    Male      middle
# alumno2  Alice   10  Female  elementary

# %%
df.rename(index={'alumno1':'student1'})
# Out:
#          nombre  edad    sexo   educacion
# student1    Tom    15    Male      middle
# alumno2   Alice    10  Female  elementary

# %%
# Eliminar filas y/o columnas en df

exam_data = {'math':[90,80,70], 'eng':[98,89,95],
             'music':[85,95,100], 'science':[100,90,90]}

# %%
exam_data
# Out:
# {'math': [90, 80, 70],
#  'eng': [98, 89, 95],
#  'music': [85, 95, 100],
#  'science': [100, 90, 90]}

# %%
df = pd.DataFrame(exam_data, index=['stu1', 'stu2', 'stu3'])

# %%
df
# Out:
#       math  eng  music  science
# stu1    90   98     85      100
# stu2    80   89     95       90
# stu3    70   95    100       90

# %%
df2=df[:] # Crear una copia de df en variable df2

# %%
df2.drop('stu2', inplace=True)
# Out:
# /tmp/ipython-input-3113900722.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop('stu2', inplace=True)

# %%
df2
# Out:
#       math  eng  music  science
# stu1    90   98     85      100
# stu3    70   95    100       90

# %%
df2.drop('eng', axis=1, inplace=True) # https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html
# Out:
# /tmp/ipython-input-1176221059.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop('eng', axis=1, inplace=True) # https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html

# %%
df2
# Out:
#       math  music  science
# stu1    90     85      100
# stu3    70    100       90

# %%
diccionario = {'saludo': 'Buenos días', 'despedida': 'Chao'}
lista = ['hola', 'chao']

# %%
diccionario
# Out:
# {'saludo': 'Buenos días', 'despedida': 'Chao'}

# %%
df2
# Out:
#       math  music  science
# stu1    90     85      100
# stu3    70    100       90

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df3 = df2['math']

# %%
df3
# Out:
# stu1    90
# stu3    70
# Name: math, dtype: int64

# %%
type(df3)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Trabajo en clases
#
#
# GRUPO 1 : Slide 226 a 243
#
# GRUPO 2: Slide 244 a 265
#
# GRUPO 3: Slide 266 a 273
#
# GRUPO 4: Slide 274 a 282
#
# GRUPO 5: Slide 283 a 315
#
# GRUPO 6: Slide 316 a 339
